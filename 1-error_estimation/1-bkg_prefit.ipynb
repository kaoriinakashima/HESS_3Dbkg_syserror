# %% [markdown]
# in this notebook, we create the prefit of the bkg model per each run and save the spectrum counts and bkg (pos fit) per run.

# %%
import numpy as np
import astropy.units as u
import yaml
import utils

from gammapy.data import DataStore
from gammapy.maps import MapAxis, WcsGeom, Map
from gammapy.datasets import MapDataset
from gammapy.makers import MapDatasetMaker, SafeMaskMaker, FoVBackgroundMaker
#from gammapy.utils.regions import make_region
from gammapy.modeling.models import FoVBackgroundModel, Models
from gammapy.modeling import Fit
from gammapy.irf import Background3D

import warnings
warnings.filterwarnings('ignore')

# %%
# loading general parameters
with open("../general_config.yml", "r") as ymlfile:
    cfg = yaml.load(ymlfile, Loader=yaml.FullLoader)
conf=cfg['conf']
hesseras= ['hess1', 'hess2']
muoneff_flag= cfg['muoneff_flag']

# %%
# defining the geometry for the datasets
energy_bins = np.logspace(-1, 2, cfg['N_ebins']+1)
axis = MapAxis.from_edges(energy_bins, unit="TeV", name="energy", interp="log")
maker = MapDatasetMaker()
maker_safe_mask = SafeMaskMaker(methods=['offset-max', 'bkg-peak'], offset_max=cfg['offset_cut'] * u.deg)

# %%
overall_problem = []
for hessera in hesseras:
    runlist = np.loadtxt(f'initial_runlist_{hessera}.txt')
    muoneff_path = f'{cfg["muoneff_path"]}/{hessera}/hess1_hess2/v01c_kaori_mueff'
    
    basedir = f'{cfg["FITS_PROD"]}/{hessera}/std_{conf}_fullEnclosure'
    ds = DataStore.from_dir(basedir, f'hdu-index-bg-latest-fov-radec.fits.gz', f'obs-index-bg-latest-fov-radec.fits.gz')
    observations = ds.get_observations(runlist)
    
    result_list = []
    runs_with_problems = []
    for obs in observations:
        try:
            # taking care of the correct bkg model (if it is muoneff or official model)
            # the official model is stored in the fits tables. For the muoneff model, we will just change the path of the bkg model
            if muoneff_flag:
                if obs.obs_info['MUONEFF'] > 0.085:
                    model_CD = 'B'
                elif obs.obs_info['MUONEFF'] >= 0.075:
                    model_CD = 'D'
                else:
                    model_CD = 'C'

                if obs.obs_id >= 100000:
                    run_number= f'{obs.obs_id}'
                else:
                    run_number= f'0{obs.obs_id}'
                filename = f'{muoneff_path}_{model_CD}/hess_bkg_3d_v01c_kaori_mueff_{model_CD}_norebin_fov_radec_{run_number}.fits.gz'
                obs.bkg = Background3D.read(filename, hdu='BACKGROUND')

            geom = WcsGeom.create(skydir=obs.pointing_radec, binsz=cfg['binsz'], width=cfg['width']* u.deg, frame="icrs", axes=[axis])        
            dataset = MapDataset.create(geom=geom)
            dataset = maker.run(dataset, obs)
            dataset = maker_safe_mask.run(dataset, obs)

            # create here mask_fit
            dataset.mask_fit = Map.from_geom(geom=geom, data=np.ones_like(dataset.counts.data).astype(bool))
            coord = utils.get_mask_fov(obs.pointing_radec.ra.deg, obs.pointing_radec.dec.deg, 5)
            if coord != 0: #this means that if there are regions to be masked
                for s in coord:
                    dataset.mask_fit &= ~dataset.counts.geom.region_mask(f"icrs;circle({s[0]}, {s[1]}, {s[2]})")

            bkg_model = FoVBackgroundModel(dataset_name=dataset.name)
            dataset.models = Models([bkg_model])
            dataset.background_model.spectral_model.tilt.frozen = False

            Fit().run(datasets=[dataset])

            if dataset.background_model.spectral_model.norm.value > 0:
                c = np.nansum((dataset.counts * dataset.mask_fit *dataset.mask_safe).data, axis=(1, 2))
                b = np.nansum((dataset.npred() * dataset.mask_fit *dataset.mask_safe).data, axis=(1, 2))
                result_list.append(np.concatenate([[obs.obs_id], c, b]))
            else:
                runs_with_problems.append(obs.obs_id)
        except:
            overall_problem.append(obs.obs_id)
    
    # dividing the result of hess1, because only one file is too big
    if hessera == 'hess1':
        batch_N = 20
        batch_size = int(len(result_list)/batch_N)
        for part in range(batch_N +1):
            np.savetxt(f'results/dataspectrum_muoneff_{hessera}_part{part}.txt', np.asarray(result_list[part*batch_size: (part+1)*batch_size]))
    else:
        np.savetxt(f'results/dataspectrum_muoneff_{hessera}.txt', np.asarray(result_list))
    np.savetxt(f'results/runs_with_problems_{hessera}.txt', np.asarray(runs_with_problems))
np.savetxt(f'results/overall_problem.txt', np.asarray(overall_problem))
# Out:
# No HDU found matching: OBS_ID = 18386.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18406.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18415.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18416.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18417.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18422.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18478.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18480.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18526.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18536.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18561.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18564.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18569.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18575.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18577.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18598.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18601.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18693.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18694.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18695.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18696.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18729.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18730.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18786.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18787.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18870.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18871.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18872.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18873.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18874.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18885.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18886.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18887.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18888.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18889.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18928.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18930.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18942.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18943.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18944.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18945.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18946.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18947.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18948.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18950.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18951.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18952.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18982.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18992.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18994.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18995.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18996.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18997.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18998.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 18999.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19002.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19003.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19004.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19551.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19591.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19645.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19652.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19767.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19786.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19792.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19796.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19798.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19868.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19869.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19870.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19871.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19872.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19873.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19874.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19875.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19876.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19917.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19918.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19919.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19926.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19927.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19928.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19929.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19930.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19931.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19963.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19965.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19971.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 19998.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 20000.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 20002.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 20003.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 20004.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 20005.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 20006.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 20007.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 20008.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 20009.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 20045.0, HDU_TYPE = rad_max, HDU_CLASS = None
# No HDU found matching: OBS_ID = 20046.0, HDU_TYPE = rad_max, HDU_CLASS = None
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# Missing 'HDUCLAS2' keyword assuming 'BKG'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4203/78609272.py in <module>
#      53             runs_with_problems.append(obs.obs_id)
#      54
# ---> 55     np.savetxt(f'dataspectrum_muoneff_{hessera}_{idx}.txt', np.asarray(result_list))
#      56     np.savetxt(f'runs_with_problems_{hessera}_{idx}.txt', np.asarray(runs_with_problems))
#
# NameError: name 'idx' is not defined

# %% [markdown]
# note: the results folder has several hess1 results, splitted in parts, since there are many runs, I just did it to run in parallel
