# %% [markdown]
# # Import the Dataset
#
# In this notebook a 3D analysis of the Crab is demonstated. In addition to the usuall model parameters so called 'nuisance parameters' are fitted which account for any systematical uncertainties. These sysetmatical uncertainties are assumed to be due a missmodelling of the hardronic background.
#
# The nuisance parameters are correlated so they can only eliminate the systemtic uncertainties but not the uncorrelated statistical uncertainicies.
#
# The notebook is structed as follows:
#
# - Setting up the correlation of the nuisacane parameters
# - Fitting the model and the nuisance parameters to the data
# - Compare the results to the standard 3D fit

# %%
import gammapy 
print(f'loaded gammapy version: {gammapy.__version__} ' )
print(f'Supposed to be 0.20 (18-10-2022)' )
# Out:
# loaded gammapy version: 0.20
# Supposed to be 0.20 (18-10-2022)

# %%
#get_ipython().system('jupyter nbconvert --to script 5a-Tutorial_Nui_Par_Fitting_Crab.ipynb')
import pyximport

pyximport.install()
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
import gammapy

# from gammapy.datasets import MapDataset
from gammapy.maps import Map
from astropy.coordinates import SkyCoord, Angle
from gammapy.modeling import Fit, Parameter, Parameters, Covariance
from gammapy.datasets import MapDataset #, MapDatasetNuisance
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    create_crab_spectral_model,
    SkyModel,
    PointSpatialModel,
    ShellSpatialModel,
    GeneralizedGaussianSpatialModel,
    TemplateSpatialModel,
    LogParabolaSpectralModel,
    GaussianSpatialModel,
    DiskSpatialModel,
    PowerLawNormSpectralModel,
    Models,
    SpatialModel,
    FoVBackgroundModel,
)
from regions import CircleSkyRegion, RectangleSkyRegion
import yaml
import sys

#sys.path.append(
#    "/home/hpc/caph/mppi045h/3D_analysis/N_parameters_in_L/syserror_3d_bkgmodel/4-Fitting_nuisance_and_model_parameters"
#)
from my_dataset_maps_20 import MapDatasetNuisance
from  my_fit_20 import Fit

# %% [markdown]
# ## Standard Analysis
# Setting up the model

# %%
source = 'GC_dataset_zeta_1_muoneffTrue_edispTrue'
path = '/home/vault/caph/mppi062h/repositories/HESS_3Dbkg_syserror/2-error_in_dataset'
local_path = '/home/hpc/caph/mppi045h/3D_analysis/N_parameters_in_L/HESS_3Dbkg_syserror/2-error_in_dataset'


if source == "Crab":

    dataset_standard = MapDataset.read(f'{path}/{source}/stacked.fits')
    dataset_standard = dataset_standard.downsample(4)

    models = Models.read(f"{source}/standard_model.yml")
    
    with open(f"{source}/nui_bgmodel.yml", "r") as ymlfile:
        best_fit_bgmodel = yaml.load(ymlfile, Loader=yaml.FullLoader)
    bkg_model = FoVBackgroundModel(dataset_name=dataset_standard.name)
    bkg_model.parameters['norm'].value = best_fit_bgmodel['spectral']['parameters'][0]['value']
    bkg_model.parameters['tilt'].value = best_fit_bgmodel['spectral']['parameters'][1]['value']
    bkg_model.parameters['norm'].error = best_fit_bgmodel['spectral']['parameters'][0]['error']
    bkg_model.parameters['tilt'].error = best_fit_bgmodel['spectral']['parameters'][1]['error']
    
    models.parameters['lon_0'].frozen = True
    models.parameters['lat_0'].frozen = True
    
    models.append(bkg_model)
    dataset_standard.models = models
    ebins_display = 6,9
    print(dataset_standard)

    
if "GC" in source :
    if source =='GC':
        path_GC ='/home/hpc/caph/mppi045h/3D_analysis/N_parameters_in_L/syserror_3d_bkgmodel/2-source_dataset/GC_0.19'
        dataset_standard = MapDataset.read(f'{path_GC}/20220511_dataset002_hess1_muonflagTrue.fits')
        dataset_standard.stack(MapDataset.read(f'{path_GC}/20220511_dataset002_hess2_muonflagTrue.fits'))
        dataset_standard = dataset_standard.downsample(4)
        
    if source == 'GC_dataset_zeta_1_muoneffTrue_edispTrue':
        path_GC = '/home/vault/caph/mppi062h/repositories/GC/HESS/datasets_fits'
        dataset_standard = MapDataset.read(f'{path_GC}/dataset_zeta_1_muoneffTrue_edispTrue.fits')
        dataset_standard = dataset_standard.downsample(8)


    # Define source model for stacked fit
    from gammapy.modeling.models import (PointSpatialModel, 
                                         ExpCutoffPowerLawSpectralModel,
                                         PowerLawSpectralModel,
                                         GaussianSpatialModel,TemplateSpatialModel,
                                        PowerLawNormSpectralModel)
    spatial_model_center = PointSpatialModel(lon_0=359.9439608*u.deg, lat_0=-0.0418969*u.deg, frame='galactic') 
    spectral_model_center = ExpCutoffPowerLawSpectralModel(index=2.14, amplitude="2.55e-12 cm-2 s-1 TeV-1", reference="1 TeV", lambda_='0.093 TeV-1')
    source_model_center = SkyModel(spatial_model=spatial_model_center, spectral_model=spectral_model_center, name="src")

    spatial_model_g09 = PointSpatialModel(lon_0=0.8717549*u.deg, lat_0=0.0767488*u.deg, frame='galactic')
    spectral_model_g09 = PowerLawSpectralModel(index=2.4, amplitude="0.838e-12 cm-2 s-1 TeV-1", reference="1 TeV") # was 3e-12
    source_model_g09 = SkyModel(spatial_model=spatial_model_g09, spectral_model=spectral_model_g09, name="g09")

    spatial_model_1745 = GaussianSpatialModel(lon_0=358.6435538*u.deg, lat_0=-0.5617789*u.deg, sigma=0.179*u.deg, frame='galactic')
    spectral_model_1745 = PowerLawSpectralModel(index=2.57, amplitude="1.73e-12 cm-2 s-1 TeV-1", reference="1 TeV") # 
    source_model_1745 = SkyModel(spatial_model=spatial_model_1745, spectral_model=spectral_model_1745, name="1745")

    spatial_model_1746 = PointSpatialModel(lon_0=0.1384563*u.deg, lat_0=-0.1112664*u.deg, frame='galactic')
    spectral_model_1746 = PowerLawSpectralModel(index=2.17, amplitude="0.18e-12 cm-2 s-1 TeV-1", reference="1 TeV") # was 3e-12
    source_model_1746 = SkyModel(spatial_model=spatial_model_1746, spectral_model=spectral_model_1746, name="1746")

    spatial_model_1746308 = GaussianSpatialModel(lon_0=358.4479799*u.deg, lat_0=-1.1140008*u.deg, sigma=0.162*u.deg, frame='galactic')
    spectral_model_1746308 = PowerLawSpectralModel(index=3.27, amplitude="0.70e-12 cm-2 s-1 TeV-1", reference="1 TeV") #
    source_model_1746308 = SkyModel(spatial_model=spatial_model_1746308, spectral_model=spectral_model_1746308, name="1746308")

    spatial_model_1741 = PointSpatialModel(lon_0=358.2753545*u.deg, lat_0=0.0515537*u.deg, frame='galactic')
    spectral_model_1741 = PowerLawSpectralModel(index=2.30, amplitude="0.21e-12 cm-2 s-1 TeV-1", reference="1 TeV") # was 3e-12
    source_model_1741 = SkyModel(spatial_model=spatial_model_1741, spectral_model=spectral_model_1741, name="1741")

    diffuse_filename = "/home/saturn/caph/mppi043h/diffusiontemplate/cont_pcut_v3.fits"
    diffuse_gal = Map.read(diffuse_filename)
    print(diffuse_gal.geom.axes[0].name)
    template_diffuse = TemplateSpatialModel(
            diffuse_gal, normalize=False,
        filename = diffuse_filename
        )
    diffuse_model = SkyModel(
        spectral_model=PowerLawNormSpectralModel(),
        spatial_model=template_diffuse,
        name="Diffuse Emission",)
    
    bkg_model = FoVBackgroundModel(dataset_name=dataset_standard.name)
    bkg_model.parameters['tilt'].frozen  = False

    models = Models([source_model_center, source_model_g09, source_model_1745, source_model_1746, 
                     source_model_1746308, source_model_1741, diffuse_model, bkg_model ])
    
    
    j1745_coord = SkyCoord(358.6435538, -0.5617789, unit='deg',frame='galactic')

    skyregion_1745 = RectangleSkyRegion(center=j1745_coord, width=1*u.deg,height=1*u.deg)
    geom_2d = dataset_standard.geoms['geom'].drop('energy')
    dataset_standard.mask_safe.data[:] &= Map.from_geom(geom_2d, 
                                                        data=geom_2d.region_mask([skyregion_1745], 
                                                                                          inside=False).data).data
    
    dataset_standard.models = models
    ebins_display = 3, 6


dataset_standard.counts.sum_over_axes().plot(add_cbar=1)
binsize = dataset_standard.geoms["geom"].width[1] / dataset_standard.geoms["geom"].data_shape[1]
print(
    "spatial binsize = ",
    binsize
)
# Out:
# energy_true
# spatial binsize =  [0.16] deg

# %%
#models = Models.read(f'{source}/HESS_fixed_models.yml')
#print(models)

# %%
# %%time
fit_standarad = Fit(store_trace=False)
result_standarad = fit_standarad.run([dataset_standard])
# Out:
# Position <SkyCoord (Galactic): (l, b) in deg
#     (50.59415927, -0.0418969)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (50.59415927, -0.0418969)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (309.29376233, -0.0418969)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (309.29376233, -0.0418969)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (5.00898065, -0.0418969)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (5.00898065, -0.0418969)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.87894095, -0.0418969)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.87894095, -0.0418969)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (49.29375227, -0.5617789)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (49.29375227, -0.5617789)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (307.99335533, -0.5617789)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (307.99335533, -0.5617789)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (13.59601555, -0.5617789)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (13.59601555, -0.5617789)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (343.69109205, -0.5617789)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (343.69109205, -0.5617789)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (49.09817837, -1.1140008)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (49.09817837, -1.1140008)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (307.79778143, -1.1140008)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (307.79778143, -1.1140008)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (4.40377531, -1.1140008)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (4.40377531, -1.1140008)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (352.49218449, -1.1140008)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (352.49218449, -1.1140008)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (48.92555297, 0.0515537)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (48.92555297, 0.0515537)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (307.62515603, 0.0515537)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (307.62515603, 0.0515537)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (4.76843145, 0.0515537)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (4.76843145, 0.0515537)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (351.78227755, 0.0515537)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (351.78227755, 0.0515537)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.22939205, -0.13207117)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.22939205, -0.13207117)> is outside valid IRF map range, using nearest IRF defined within
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:2, in <module>
#
# File ~/3D_analysis/N_parameters_in_L/HESS_3Dbkg_syserror/2-error_in_dataset/my_fit_20.py:163, in Fit.run(self, datasets)
#     150 def run(self, datasets):
#     151     """Run all fitting steps.
#     152
#     153     Parameters
#    (...)
#     161         Fit result
#     162     """
# --> 163     optimize_result = self.optimize(datasets=datasets)
#     165     if self.backend not in registry.register["covariance"]:
#     166         log.warning("No covariance estimate - not supported by this backend.")
#
# File ~/3D_analysis/N_parameters_in_L/HESS_3Dbkg_syserror/2-error_in_dataset/my_fit_20.py:207, in Fit.optimize(self, datasets)
#     203 compute = registry.get("optimize", backend)
#     204 # TODO: change this calling interface!
#     205 # probably should pass a fit statistic, which has a model, which has parameters
#     206 # and return something simpler, not a tuple of three things
# --> 207 factors, info, optimizer = compute(
#     208     parameters=parameters,
#     209     function=datasets.stat_sum,
#     210     store_trace=self.store_trace,
#     211     **kwargs,
#     212 )
#     214 if backend == "minuit":
#     215     self._minuit = optimizer
#
# File ~/anaconda3/envs/gammapy-0.20/lib/python3.8/site-packages/gammapy/modeling/iminuit.py:79, in optimize_iminuit(parameters, function, store_trace, **kwargs)
#      73 migrad_opts = kwargs.pop("migrad_opts", {})
#      75 minuit, minuit_func = setup_iminuit(
#      76     parameters=parameters, function=function, store_trace=store_trace, **kwargs
#      77 )
# ---> 79 minuit.migrad(**migrad_opts)
#      81 factors = minuit.values
#      82 info = {
#      83     "success": minuit.valid,
#      84     "nfev": minuit.nfcn,
#      85     "message": _get_message(minuit, parameters),
#      86     "trace": minuit_func.trace,
#      87 }
#
# File ~/anaconda3/envs/gammapy-0.20/lib/python3.8/site-packages/iminuit/minuit.py:686, in Minuit.migrad(self, ncall, iterate)
#     684 if self._precision is not None:
#     685     migrad.precision = self._precision
# --> 686 fm = migrad(ncall, self._tolerance)
#     687 if fm.is_valid or fm.has_reached_call_limit:
#     688     break
#
# File ~/anaconda3/envs/gammapy-0.20/lib/python3.8/site-packages/gammapy/modeling/iminuit.py:25, in MinuitLikelihood.fcn(self, *factors)
#      22 def fcn(self, *factors):
#      23     self.parameters.set_parameter_factors(factors)
# ---> 25     total_stat = self.function()
#      27     if self.store_trace:
#      28         self.store_trace_iteration(total_stat)
#
# File ~/3D_analysis/N_parameters_in_L/HESS_3Dbkg_syserror/2-error_in_dataset/my_dataset_core_20.py:250, in Datasets.stat_sum(self)
#     248 # TODO: add parallel evaluation of likelihoods
#     249 for dataset in self:
# --> 250     stat_sum += dataset.stat_sum()
#     251 return stat_sum
#
# File ~/anaconda3/envs/gammapy-0.20/lib/python3.8/site-packages/gammapy/datasets/map.py:1061, in MapDataset.stat_sum(self)
#    1059 def stat_sum(self):
#    1060     """Total likelihood given the current model parameters."""
# -> 1061     counts, npred = self.counts.data.astype(float), self.npred().data
#    1063     if self.mask is not None:
#    1064         return cash_sum_cython(counts[self.mask.data], npred[self.mask.data])
#
# File ~/anaconda3/envs/gammapy-0.20/lib/python3.8/site-packages/gammapy/datasets/map.py:432, in MapDataset.npred(self)
#     424 def npred(self):
#     425     """Total predicted source and background counts
#     426
#     427     Returns
#    (...)
#     430         Total predicted counts
#     431     """
# --> 432     npred_total = self.npred_signal()
#     434     if self.background:
#     435         npred_total += self.npred_background()
#
# File ~/anaconda3/envs/gammapy-0.20/lib/python3.8/site-packages/gammapy/datasets/map.py:510, in MapDataset.npred_signal(self, model_name)
#     508     if evaluator.contributes:
#     509         npred = evaluator.compute_npred()
# --> 510         npred_total.stack(npred)
#     512 return npred_total
#
# File ~/anaconda3/envs/gammapy-0.20/lib/python3.8/site-packages/gammapy/maps/wcs/ndmap.py:837, in WcsNDMap.stack(self, other, weights, nan_to_num)
#     835     parent_slices, cutout_slices = None, None
#     836 elif self.geom.is_aligned(other.geom):
# --> 837     cutout_slices = other.geom.cutout_slices(self.geom)
#     839     slices = cutout_slices["parent-slices"]
#     840     parent_slices = Ellipsis, slices[0], slices[1]
#
# File ~/anaconda3/envs/gammapy-0.20/lib/python3.8/site-packages/gammapy/maps/wcs/geom.py:180, in WcsGeom.cutout_slices(self, geom, mode)
#     165 def cutout_slices(self, geom, mode="partial"):
#     166     """Compute cutout slices.
#     167
#     168     Parameters
#    (...)
#     178         Dictionary containing "parent-slices" and "cutout-slices".
#     179     """
# --> 180     position = geom.to_image().coord_to_pix(self.center_skydir)
#     181     slices = overlap_slices(
#     182         large_array_shape=geom.data_shape[-2:],
#     183         small_array_shape=self.data_shape[-2:],
#     184         position=position[::-1],
#     185         mode=mode,
#     186     )
#     187     return {
#     188         "parent-slices": slices[0],
#     189         "cutout-slices": slices[1],
#     190     }
#
# File ~/anaconda3/envs/gammapy-0.20/lib/python3.8/site-packages/gammapy/maps/wcs/geom.py:622, in WcsGeom.coord_to_pix(self, coords)
#     621 def coord_to_pix(self, coords):
# --> 622     coords = MapCoord.create(coords, frame=self.frame, axis_names=self.axes.names)
#     624     if coords.size == 0:
#     625         return tuple([np.array([]) for i in range(coords.ndim)])
#
# File ~/anaconda3/envs/gammapy-0.20/lib/python3.8/site-packages/gammapy/maps/coord.py:216, in MapCoord.create(cls, data, frame, axis_names)
#     214     return cls._from_tuple(data, frame=frame, axis_names=axis_names)
#     215 elif isinstance(data, SkyCoord):
# --> 216     return cls._from_tuple((data,), frame=frame, axis_names=axis_names)
#     217 else:
#     218     raise TypeError(f"Unsupported input type: {type(data)!r}")
#
# File ~/anaconda3/envs/gammapy-0.20/lib/python3.8/site-packages/gammapy/maps/coord.py:151, in MapCoord._from_tuple(cls, coords, frame, axis_names)
#     149     return cls._from_lonlat(coords, frame=frame, axis_names=axis_names)
#     150 elif isinstance(coords[0], SkyCoord):
# --> 151     lon, lat, frame = skycoord_to_lonlat(coords[0], frame=frame)
#     152     coords = (lon, lat) + coords[1:]
#     153     return cls._from_lonlat(coords, frame=frame, axis_names=axis_names)
#
# File ~/anaconda3/envs/gammapy-0.20/lib/python3.8/site-packages/gammapy/maps/coord.py:20, in skycoord_to_lonlat(skycoord, frame)
#      10 """Convert SkyCoord to lon, lat, frame.
#      11
#      12 Returns
#    (...)
#      17     Latitude in degrees.
#      18 """
#      19 if frame:
# ---> 20     skycoord = skycoord.transform_to(frame)
#      22 return skycoord.data.lon.deg, skycoord.data.lat.deg, skycoord.frame.name
#
# File ~/anaconda3/envs/gammapy-0.20/lib/python3.8/site-packages/astropy/coordinates/sky_coordinate.py:648, in SkyCoord.transform_to(self, frame, merge_attributes)
#     645 # Get frame attributes, allowing defaults to be overridden by
#     646 # explicitly set attributes of the source if ``merge_attributes``.
#     647 for attr in frame_transform_graph.frame_attributes:
# --> 648     self_val = getattr(self, attr, None)
#     649     frame_val = getattr(frame, attr, None)
#     650     if (frame_val is not None
#     651         and not (merge_attributes
#     652                  and frame.is_frame_attr_default(attr))):
#
# File ~/anaconda3/envs/gammapy-0.20/lib/python3.8/site-packages/astropy/coordinates/sky_coordinate.py:842, in SkyCoord.__getattr__(self, attr)
#     838 # Anything in the set of all possible frame_attr_names is handled
#     839 # here. If the attr is relevant for the current frame then delegate
#     840 # to self.frame otherwise get it from self._<attr>.
#     841 if attr in frame_transform_graph.frame_attributes:
# --> 842     if attr in self.frame.get_frame_attr_names():
#     843         return getattr(self.frame, attr)
#     844     else:
#
# File ~/anaconda3/envs/gammapy-0.20/lib/python3.8/site-packages/astropy/coordinates/baseframe.py:698, in BaseCoordinateFrame.get_frame_attr_names(cls)
#     695 @classmethod
#     696 def get_frame_attr_names(cls):
#     697     return {name: getattr(cls, name)
# --> 698             for name in cls.frame_attributes}
#
# KeyboardInterrupt:

# %% [markdown]
# The first two energybins of the dataset are not fitted well ...

# %%
res_standard = (
    dataset_standard.residuals("diff/sqrt(model)")
    .slice_by_idx(dict(energy=slice(ebins_display[0],ebins_display[1] )))
    .smooth(0.1 * u.deg)
)
vmax = np.nanmax(np.abs(res_standard.data))
res_standard.plot_grid(add_cbar=1, vmax=vmax, vmin=-vmax, cmap="coolwarm");

# %%
kwargs_spectral = dict()
kwargs_spectral["region"] = CircleSkyRegion(
    dataset_standard.geoms["geom"].center_skydir, radius=3 * u.deg
)
kwargs_spectral["method"] = "diff/sqrt(model)"
dataset_standard.plot_residuals(kwargs_spectral=kwargs_spectral);

# %% [markdown]
# ## Nuisance Parameters
#
# Firstly, the expected ampitude of the systematics for the different energybins are read. They can either be in terms of std or in percentage of the bg. Since in the end the nuisance parameters are in percentage of bg, we want the amplitude in the same unit..
#
# Here, two things are used to save computation time:
# - The nuisance parameters are computed only within the first two energybins of the analysis (index 4 and 5) exemplary to save computation time. The indices are defined as `i_start` and `i_end`. This approximation is fine since the systematic uncertainites are known to be the largest at the smaller energies.
# - The nuisance parameter have a larger binsize than the counts cube. The downsampling factor `downsampling_factor` denotes that. This way, one nuisance parameter acts on multiple neighbor bins and the systematic uncertainty is averaged over them. The geometry of this downsampled nuisance parameter cube is saved in `dataset.geoms['geom_down']`.

# %% [markdown]
# ### Systematic Amplitude

# %%
bg = (
    dataset_standard.background
    .data.sum(axis=2)
    .sum(axis=1)
)

#sysamplitude_std = np.loadtxt(f'{source}/sysamplitude.txt')
# Convert to %:
#sysamplitude_std /= np.sqrt(bg)


sysamplitude_percentage = np.loadtxt((f'{local_path}/{source}/sysamplitude_percentage.txt'))
# Convert to %:
sysamplitude_percentage /= 100
print("sysamplitude_percentage:",sysamplitude_percentage)


#choose between the following:
sigma = sysamplitude_percentage 
#sigma = sysamplitude_std 


emask = sigma >0
print("Estimated systematic uncertainty: ")
print()
print("Ebin               [Counts]    [% BG]")

for i, e in enumerate(dataset_standard.geoms['geom'].axes[0].center.value):
    e_start, e_end = (
        dataset_standard.geoms["geom"].axes[0].edges[ i],
        dataset_standard.geoms["geom"].axes[0].edges[i + 1],
    )
    sys_percent = sigma[i]
    sys_counts =  sigma[i] * bg[i]
    

    print(
        f"{np.round(e_start.value,1):<4} : {np.round(e_end.value,1):<6} TeV:  {np.round(sys_counts,0):<10}  {np.round(sys_percent,3):<5}  "
        )
# Out:
# sysamplitude_percentage: [ 0.          0.          0.          0.10684213 -0.07940953  0.07225644
#  -0.02244597  0.01291108 -0.02737746  0.00089018  0.00737546  0.00848398
#  -0.00662282  0.11950578  0.07077386  0.17897078  0.24530355  0.31103884
#   0.26976106  0.50109376  0.          0.          0.          0.        ]
# Estimated systematic uncertainty:
#
# Ebin               [Counts]    [% BG]
# 0.1  : 0.1    TeV:  0.0         0.0
# 0.1  : 0.2    TeV:  0.0         0.0
# 0.2  : 0.2    TeV:  0.0         0.0
# 0.2  : 0.3    TeV:  1491.0      0.107
# 0.3  : 0.4    TeV:  -3685.0     -0.079
# 0.4  : 0.6    TeV:  2719.0      0.072
# 0.6  : 0.7    TeV:  -797.0      -0.022
# 0.7  : 1.0    TeV:  370.0       0.013
# 1.0  : 1.3    TeV:  -598.0      -0.027
# 1.3  : 1.8    TeV:  15.0        0.001
# 1.8  : 2.4    TeV:  94.0        0.007
# 2.4  : 3.2    TeV:  74.0        0.008
# 3.2  : 4.2    TeV:  -41.0       -0.007
# 4.2  : 5.6    TeV:  407.0       0.12
# 5.6  : 7.5    TeV:  128.0       0.071
# 7.5  : 10.0   TeV:  238.0       0.179
# 10.0 : 13.3   TeV:  232.0       0.245
# 13.3 : 17.8   TeV:  209.0       0.311
# 17.8 : 23.7   TeV:  128.0       0.27
# 23.7 : 31.6   TeV:  167.0       0.501
# 31.6 : 42.2   TeV:  0.0         0.0
# 42.2 : 56.2   TeV:  0.0         0.0
# 56.2 : 75.0   TeV:  0.0         0.0
# 75.0 : 100.0  TeV:  0.0         0.0

# %% [markdown]
# ### Downsampling Factor

# %%
angular_size_file = f'{source}/angular_size.txt'
angular_size = np.loadtxt(angular_size_file)
ndim_spatial = dataset_standard.geoms['geom'].data_shape[1]
print("Current Binning:", ndim_spatial)
possible_downsampling_factors = []
possible_binsizes = []
for i in range(1, ndim_spatial):
    if (ndim_spatial%i == 0):
        possible_downsampling_factors.append(i)
        possible_binsizes.append(binsize[0].value * i)


print(f"Possible downsampling factors: {possible_downsampling_factors}")
print(f"Resulting Binsize: {possible_binsizes}")

downsampling_factor_index = -1
while (possible_binsizes[downsampling_factor_index] > angular_size):
    downsampling_factor_index -=1
downsampling_factor =    possible_downsampling_factors[downsampling_factor_index]

# ##############################
downsampling_factor = 10
# ##############################


print()
print(f"Chosen Downsampling Factor: \n {downsampling_factor}.")
print(f"This will result in a Binsize of the Nuisance Parameters of \n {possible_binsizes[downsampling_factor_index]} deg.")
print(f"Which is smaller than the observed angular size of the systematics of \n {angular_size} deg.")

geom_down = dataset_standard.downsample(downsampling_factor).geoms['geom']
# Out:
# Current Binning: 50
# Possible downsampling factors: [1, 2, 5, 10, 25]
# Resulting Binsize: [0.16, 0.32, 0.8, 1.6, 4.0]
#
# Chosen Downsampling Factor:
#  10.
# This will result in a Binsize of the Nuisance Parameters of
#  0.32 deg.
# Which is smaller than the observed angular size of the systematics of
#  0.75 deg.

# %% [markdown]
# ### Nuisance Mask

# %% [markdown]
# The `nuisance_mask` describes where in the dataset the nuisance parameters are evaulated. It has the same geometry as `dataset.geoms['geom_down']`.

# %% [markdown]
# #### Option 1:
# define start and stop by hand

# %%
i_start, i_end = 6,7
nuisance_mask_hand = (
    dataset_standard.geoms["geom"]
    .energy_mask(
        energy_min=dataset_standard.geoms["geom"].axes[0].edges[i_start],
        energy_max=dataset_standard.geoms["geom"].axes[0].edges[i_end],
    )
    .downsample(downsampling_factor)
)

# %% [markdown]
# #### Option 2:
# Read in the sysamplitudes and only fit the nuisance parameters where sys amplitude >0

# %%
print('Creating Mask for Nuisance Parameters where sysamplitude==0')
nui_mask = np.abs(sigma)>0
print('nui_mask:',nui_mask)
nuisance_mask = Map.from_geom(geom_down, dtype=bool)
for e, n in enumerate(nui_mask):
    nuisance_mask.data[e,:,:] = n
nuisance_mask &= nuisance_mask_hand
emask = nuisance_mask.data.mean(axis=2).mean(axis=1)
emask = list(map(bool,emask))
print(emask)
# Out:
# Creating Mask for Nuisance Parameters where sysamplitude==0
# nui_mask: [False False False  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True False False False False]
# [False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]

# %% [markdown]
# ### Nuisance Parameters

# %%
threshold = 1#10000
bg_map_eaxis = dataset_standard.background.data.sum(axis = 2).sum(axis=1)


print("                                     sys * thresh < stat:")
for i in range(len(bg_map_eaxis)):
    stat =np.round(np.sqrt(bg_map_eaxis[i]) )
    sys = np.round(np.abs(sigma[i]*bg_map_eaxis[i]))
    print(f"BG: {np.round(bg_map_eaxis[i]):<10} pm {stat:<14}   |  {sys}")
    print(f" { ((sys * threshold) < stat):>60}")
# Out:
#                                      sys * thresh < stat:
# BG: 0.0        pm 0.0              |  0.0
#                                                             0
# BG: 0.0        pm 0.0              |  0.0
#                                                             0
# BG: 0.0        pm 0.0              |  0.0
#                                                             0
# BG: 13954.0    pm 118.0            |  1491.0
#                                                             0
# BG: 46407.0    pm 215.0            |  3685.0
#                                                             0
# BG: 37632.0    pm 194.0            |  2719.0
#                                                             0
# BG: 35509.0    pm 188.0            |  797.0
#                                                             0
# BG: 28641.0    pm 169.0            |  370.0
#                                                             0
# BG: 21857.0    pm 148.0            |  598.0
#                                                             0
# BG: 16490.0    pm 128.0            |  15.0
#                                                             1
# BG: 12760.0    pm 113.0            |  94.0
#                                                             1
# BG: 8747.0     pm 94.0             |  74.0
#                                                             1
# BG: 6200.0     pm 79.0             |  41.0
#                                                             1
# BG: 3410.0     pm 58.0             |  407.0
#                                                             0
# BG: 1809.0     pm 43.0             |  128.0
#                                                             0
# BG: 1329.0     pm 36.0             |  238.0
#                                                             0
# BG: 944.0      pm 31.0             |  232.0
#                                                             0
# BG: 671.0      pm 26.0             |  209.0
#                                                             0
# BG: 475.0      pm 22.0             |  128.0
#                                                             0
# BG: 334.0      pm 18.0             |  167.0
#                                                             0
# BG: 245.0      pm 16.0             |  0.0
#                                                             1
# BG: 179.0      pm 13.0             |  0.0
#                                                             1
# BG: 130.0      pm 11.0             |  0.0
#                                                             1
# BG: 102.0      pm 10.0             |  0.0
#                                                             1

# %%
for ii in np.arange(len(sigma)):
    print( np.abs(sigma[ii]) >0.0 , emask[ii])
# Out:
# False False
# False False
# False False
# True False
# True False
# True False
# True True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False False
# False False
# False False
# False False

# %%
# new way to compute correlation matrix to make it symmetric/ invertible
# into Gaussian: sigma **2  * exp(...), where sigma  is the systematic amplitude in %
# if it is saved in terms of std it has to be transformed! 
ndim_spectral_nui = int(sum(emask))
ndim_spatial_nui_1D = geom_down.data_shape[1]
ndim_spatial_nui = ndim_spatial_nui_1D **2
ndim_3D_nui = ndim_spectral_nui *  ndim_spatial_nui

sys_map = Map.from_geom(geom_down).slice_by_idx(dict(energy=slice(0,int(ndim_spectral_nui))))
e = 0
sys_map.data = np.ones_like(sys_map.data)
for ii in np.arange(len(sigma)):
    if np.abs(sigma[ii]) >0.0 and emask[ii]:
        if dataset_standard.npred_background().downsample(downsampling_factor).data[ii,:,:].sum() > 0:
            sys_map.data[e,:,:] *= sigma[ii] **2
            print(sigma[ii])
        e+=1
# Out:
# -0.022445968

# %%
# Freeze Nuisance parameters at the edges of the analysis
threshold = 1
bg_map  = dataset_standard.background.downsample(downsampling_factor)
bg = bg_map.data[emask].flatten()
stat_err_ = np.sqrt(bg)
Nuisance_parameters = [Parameter(name = "db"+str(i), value =0,frozen = False)  
            if sys_map.data.flatten()[i]  * threshold < stat_err_[i] 
            else  Parameter(name = "db"+str(i), value = 0,frozen = True)
      for i in range(ndim_3D_nui)]
ii = 0
for i in Nuisance_parameters:
    if i.frozen == False:
        ii += 1
print(ii, ' free Nuisance Parameters out of ', ndim_3D_nui)
Nuisance_parameters = Parameters( Nuisance_parameters)
# Out:
# 21  free Nuisance Parameters out of  25

# %% [markdown]
# The total amount of nuisance parameters in the dataset can now be computed (defined as `ndim_3D_nui`). The number of spatial and spectral dimensions of the nuisance parameter cube is defined as `ndim_spatial_nui` and `ndim_spectral_nui` since it is needed for the computation of the correlation matrix. Note that here the FoV is expected to be squared.
# The nuisance parameters are defined with their initial value set to `0`.

# %% [markdown]
# ## Correlation of Nuisance Parameters

# %% [markdown]
# The Gaussian correlation matrix is the kronecker product of the spatial $K_{ij}$ and the spectral correlation matrix $K_{e}$: \
# $ K_{ije} = K_{e} \cdot K_{ij} $
#
# The spatial correlation matrix is defined as follows:
#
# $K_{ij} = \exp \left( \frac{ -  (r_i - r_j ) ^2} {2\cdot l_{corr}^2}    \right)$,\
# where $l_{corr}$ describes the spatial correlation length. Note that the correlation amplitude in the spatial correlation matrix is set to $1$. This is due to the fact, that we assume in the first order a uniformly distributed systematic uncertainty over the FoV. The correaltion amplitude was evaluated over the summed up FoV for each of the energybins and is therefore used in the spectral correlation desciption only.
#
# The spectral correaltion matrix is:
#
# $K_{s} = \sigma_s $, \
# where $\sigma_s$ is the correlation amplitude in the spectral bin $s$. Note that here the correlation is in fact not Gaussian and there is no correlation between the energy bins. The correaltion is intrinsically included in the way the spectral correlation amplitude is defined.
#
#
# Therefor for the Gaussian correlation matrix $K_{ije}$ of the nuisance parameter one needs two parameters:
# - `l_corr`: the spatial correlation length in deg. For instance, a Fourier transformation of the residual map of the standard analysis can be used to estimate the correlation length. Generally, it is important to choose a correaltion length greater than the bin size of the counts cube to avoid fitting the nuisance parameters without any correlation which can lead to overfitting the data.
# - `sysamplitude`: list of correlation amplitudes for the different energybins. The strength of the systematics can be estimated of the spectral residual points when taking only the OFF regions of all runs into account. Here, these obtained values are divided by the amount of spatial bins they were computed for.

# %%
l_corr = 0.08

# %% [markdown]
# The spatial correlation matrix is computed with two helper maps to compute the separation angle between two spatial bins. Afterwards, the systematic amplitude is set as the diagonal of the spectral correlation matrix and the kroneker product of the two is returned as the overall correlation matrix.

# %%
geom_down = nuisance_mask.geom
helper_map = Map.from_geom(geom_down).slice_by_idx(dict(energy=slice(0, 1)))
helper_map2 = helper_map.copy()


def compute_K_matrix(l_deg):
    corr_matrix_spatial = np.identity(ndim_spatial_nui)
    for b_0 in range(ndim_spatial_nui_1D):
        for l_0 in range(ndim_spatial_nui_1D):
            i = b_0 * ndim_spatial_nui_1D + l_0
            C = SkyCoord(
                helper_map.geom.pix_to_coord((l_0, b_0, 0))[0],
                helper_map.geom.pix_to_coord((l_0, b_0, 0))[1],
                frame=geom_down.frame,
            )
            helper_map.data[0, :, :] = C.separation(
                geom_down.to_image().get_coord().skycoord
            ).value
            helper_map2.data = np.zeros(ndim_spatial_nui_1D ** 2).reshape(
                helper_map2.geom.data_shape
            )
            helper_map2.data[0, :, :] = np.exp(
                -0.5 * helper_map.data[0, :, :] ** 2 / l_deg ** 2
            )
            corr_matrix_spatial[i, :] = helper_map2.data.flatten()

    corr_matrix_spectral = np.identity(ndim_spectral_nui)
    for e in range((ndim_spectral_nui)):
        corr_matrix_spectral[e, e] = sigma[emask][e] ** 2
    return np.kron(corr_matrix_spectral, corr_matrix_spatial)

# %%
correlation_matrix = compute_K_matrix(l_corr*10)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlation_matrix)  # interpolation='nearest')
fig.colorbar(cax);
print("Maximal expected sys amplitude in % of bg:", np.sqrt(correlation_matrix.max() ) * 100)
print("Maximal sigma:", sigma[emask].max()* 100)

name = f'plots/Example_corr_matrix.png'
fig.savefig(name, dpi=300, bbox_inches = 'tight')
# Out:
# Maximal expected sys amplitude in % of bg: 2.2445968
# Maximal sigma: -2.2445968

# %% [markdown]
# # Initiate the MapDatasetNuisance
#
# The MapDatasetNuisance class takes in addition to the MapDataset class:
# - `inv_corr_matrix`: The inverse of the correlation matrix
# - ` N_parameters`: The nuisance parameters
# - `nuisance_mask`: Mask to help evaluating the nuisance parameters in the background prediction

# %%
dataset_N = MapDatasetNuisance(
    background=dataset_standard.background,
    exposure=dataset_standard.exposure,
    psf=dataset_standard.psf,
    edisp=dataset_standard.edisp,
    mask_fit=dataset_standard.mask_fit,
    mask_safe=dataset_standard.mask_safe,
    counts=dataset_standard.counts,
    inv_corr_matrix=np.linalg.inv(correlation_matrix),
    N_parameters=Nuisance_parameters,
    nuisance_mask=nuisance_mask,
)

bkg_model = FoVBackgroundModel(dataset_name=dataset_N.name)
bkg_model.parameters["tilt"].frozen = False
models_N = models.copy()
models_N.append(bkg_model)
dataset_N.models = models_N
dataset_N.npred_background()
print(dataset_N)
# Out:
# MapDatasetNuisance
# ------------------
#
#   Name                            : lcBprnzI
#
#   Total counts                    : 230006
#   Total background counts         : 221235.17
#   Total excess counts             : 8770.83
#
#   Predicted counts                : 229974.31
#   Predicted background counts     : 221235.18
#   Predicted excess counts         : 8739.13
#
#   Exposure min                    : 4.84e-01 m2 s
#   Exposure max                    : 7.76e+10 m2 s
#
#   Number of total bins            : 60000
#   Number of fit bins              : 26072
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : -1076661.30
#
#   Number of models                : 8
#   Number of parameters            : 44
#   Number of free parameters       : 30
#
#   Number of Nuisance parameters   : 25
#   Number of free Nuisance parameters: 21

# %%
## Check the mask:
Nuisance_parameters_check = Nuisance_parameters.copy()
for N in Nuisance_parameters_check.free_parameters:
    N.value = 1
dataset_N.N_parameters = Nuisance_parameters_check
dataset_N.N_map().plot_grid(add_cbar =1, vmin = 0, vmax = 1);

dataset_N.N_parameters = Nuisance_parameters

fig = plt.gcf()

name = f'{source}/plots/nuisance_mask.png'
fig.savefig(name, dpi=300, bbox_inches = 'tight')

# %% [markdown]
# ## Running the Fit

# %%
# %%time
fit_N = Fit(store_trace=False)
result_N = fit_N.run([dataset_N])
# Out:
# Position <SkyCoord (Galactic): (l, b) in deg
#     (50.58721219, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (50.58721219, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (309.25680758, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (309.25680758, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (4.98853012, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (4.98853012, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (49.34351704, -0.25884741)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (49.34351704, -0.25884741)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (308.01311243, -0.25884741)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (308.01311243, -0.25884741)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (3.74483496, -0.25884741)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (3.74483496, -0.25884741)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (353.6117945, -0.25884741)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (353.6117945, -0.25884741)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (49.13517611, -1.1122907)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (49.13517611, -1.1122907)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (307.8047715, -1.1122907)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (307.8047715, -1.1122907)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (3.53649404, -1.1122907)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (3.53649404, -1.1122907)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (353.40345357, -1.1122907)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (353.40345357, -1.1122907)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (48.94503064, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (48.94503064, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (307.61462603, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (307.61462603, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (6.78376029, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (6.78376029, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (349.77589638, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (349.77589638, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (329.5228885, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (329.5228885, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (342.18918908, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (342.18918908, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (20.18809081, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (20.18809081, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.36214168, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.36214168, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.34883763, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.34883763, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.01768404)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.01768404)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (356.8524542, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (356.8524542, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (26.3249077, 0.13642672)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (26.3249077, 0.13642672)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (18.73260277, 0.13622976)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (18.73260277, 0.13622976)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (26.3249077, 0.13642672)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (26.3249077, 0.13642672)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (349.78896942, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (349.78896942, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.36214168, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.36214168, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.34883763, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.34883763, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (349.78896942, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (349.78896942, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 0.32613079)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 0.32613079)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.36844432)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.36844432)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (27.93488702, 0.13642672)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (27.93488702, 0.13642672)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (24.71492838, 0.13642672)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (24.71492838, 0.13642672)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (42.42470088, 0.13642672)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (42.42470088, 0.13642672)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (10.22511451, 0.13642672)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (10.22511451, 0.13642672)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (26.3249077, 0.1526438)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (26.3249077, 0.1526438)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (30.34236809, 0.13653094)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (30.34236809, 0.13653094)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.1495136, 0.13647405)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.1495136, 0.13647405)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (45.52069196, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (45.52069196, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (304.19028735, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (304.19028735, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 3.4508812)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 3.4508812)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -3.49316355)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -3.49316355)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (189.14744545, 0.13647405)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (189.14744545, 0.13647405)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (227.15158175, 0.13647405)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (227.15158175, 0.13647405)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.1495136, 0.2986446)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.1495136, 0.2986446)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.1495136, -0.02569694)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.1495136, -0.02569694)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.1495136, 0.13647405)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.1495136, 0.13647405)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.52827071, 0.13648388)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.52827071, 0.13648388)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (141.50751271, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (141.50751271, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (208.2034666, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (208.2034666, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 33.85377837)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 33.85377837)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -33.89298084)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -33.89298084)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (198.55933706, 0.13648522)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (198.55933706, 0.13648522)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (218.60070008, 0.13648522)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (218.60070008, 0.13648522)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.58001857, 1.75808388)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.58001857, 1.75808388)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.58001857, -1.48515775)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.58001857, -1.48515775)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.58001857, 0.13648522)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.58001857, 0.13648522)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (21.37572018, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (21.37572018, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (328.33525912, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (328.33525912, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (288.3563617, 0.13648479)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (288.3563617, 0.13648479)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (128.76999187, 0.13648479)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (128.76999187, 0.13648479)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.56317679, 16.26374583)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.56317679, 16.26374583)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.56317679, -15.99519573)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.56317679, -15.99519573)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.56317679, 0.13648479)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.56317679, 0.13648479)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (260.05779496, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (260.05779496, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (89.65318435, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (89.65318435, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (106.44837187, 0.13648358)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (106.44837187, 0.13648358)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (310.58467354, 0.13648358)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (310.58467354, 0.13648358)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51652271, 43.26802447)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51652271, 43.26802447)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51652271, -43.02847325)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51652271, -43.02847325)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51652271, 0.13648358)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51652271, 0.13648358)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.72103325, 0.13648888)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.72103325, 0.13648888)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.15766645, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.15766645, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.55331285, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.55331285, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (141.98905288, 0.13648799)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (141.98905288, 0.13648799)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (275.38469928, 0.13648799)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (275.38469928, 0.13648799)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.68687608, 43.26802834)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.68687608, 43.26802834)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.68687608, -43.02846937)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.68687608, -43.02846937)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.68687608, 0.13648799)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.68687608, 0.13648799)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.78703757, 0.13649059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.78703757, 0.13649059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.24241202, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.24241202, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.46856729, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.46856729, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.17395993, 0.13649059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.17395993, 0.13649059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (275.40011521, 0.13649059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (275.40011521, 0.13649059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.78703757, 43.26803062)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.78703757, 43.26803062)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.78703757, -43.02846709)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.78703757, -43.02846709)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.78703757, 0.13649059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.78703757, 0.13649059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.90131276, 0.13649356)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.90131276, 0.13649356)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.37860748, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.37860748, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.33237183, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.33237183, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.42443058, 0.13649356)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.42443058, 0.13649356)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (275.37819493, 0.13649356)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (275.37819493, 0.13649356)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.90131276, 43.26803322)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.90131276, 43.26803322)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.90131276, -43.02846449)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.90131276, -43.02846449)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.90131276, 0.13649356)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.90131276, 0.13649356)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.47275915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.47275915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.23822016, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.23822016, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.51270619, 0.13649341)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.51270619, 0.13649341)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (275.27816719, 0.13649341)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (275.27816719, 0.13649341)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.89543669, 43.26803308)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.89543669, 43.26803308)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.89543669, -43.02846462)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.89543669, -43.02846462)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.89543669, 0.13649341)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.89543669, 0.13649341)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.79470938, 0.13649079)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.79470938, 0.13649079)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.52562026, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.52562026, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.18535905, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.18535905, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.45718354, 0.13649059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.45718354, 0.13649059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (275.11692232, 0.13649059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (275.11692232, 0.13649059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.78705293, 43.26803062)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.78705293, 43.26803062)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.78705293, -43.02846709)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.78705293, -43.02846709)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.78705293, 0.13649059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.78705293, 0.13649059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.68673772, 0.13648799)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.68673772, 0.13648799)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.55846296, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.55846296, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.15251634, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.15251634, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.38971103, 0.13648799)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.38971103, 0.13648799)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (274.98376441, 0.13648799)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (274.98376441, 0.13648799)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.68673772, 43.26802834)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.68673772, 43.26802834)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.68673772, -43.02846938)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.68673772, -43.02846938)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.68673772, 0.13648799)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.68673772, 0.13648799)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.52608772, 0.13648382)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.52608772, 0.13648382)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.58538231, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.58538231, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.125597, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.125597, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.25598038, 0.13648382)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.25598038, 0.13648382)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (274.79619507, 0.13648382)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (274.79619507, 0.13648382)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.52608772, 43.26802468)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.52608772, 43.26802468)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.52608772, -43.02847304)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.52608772, -43.02847304)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.52608772, 0.13648382)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.52608772, 0.13648382)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.36768296, 0.13647971)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.36768296, 0.13647971)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.61611882, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.61611882, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.09486049, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.09486049, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (94.9855423, 0.13648156)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (94.9855423, 0.13648156)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (321.89187934, 0.13648156)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (321.89187934, 0.13648156)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.43871082, 43.2680227)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.43871082, 43.2680227)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.43871082, -43.02847503)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
# ...
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.30577, 0.13648349)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.30577, 0.13648349)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (274.72041294, 0.13648349)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (274.72041294, 0.13648349)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51309147, 43.26802439)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51309147, 43.26802439)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51309147, -43.02847333)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51309147, -43.02847333)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51309147, 0.13648349)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51309147, 0.13648349)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.64816828, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.64816828, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.06281103, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.06281103, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.305764, 0.13648349)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.305764, 0.13648349)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (274.72040676, 0.13648349)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (274.72040676, 0.13648349)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51308538, 43.26802439)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51308538, 43.26802439)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51308538, -43.02847333)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51308538, -43.02847333)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51308538, 0.13648349)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51308538, 0.13648349)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.64817019, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.64817019, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.06280911, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.06280911, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.30538482, 0.13648348)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.30538482, 0.13648348)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (274.72002375, 0.13648348)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (274.72002375, 0.13648348)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51270428, 43.26802438)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51270428, 43.26802438)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51270428, -43.02847334)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51270428, -43.02847334)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51270428, 0.13648348)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51270428, 0.13648348)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.64817511, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.64817511, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.0628042, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.0628042, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.30510971, 0.13648347)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.30510971, 0.13648347)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (274.71973881, 0.13648347)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (274.71973881, 0.13648347)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51242426, 43.26802437)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51242426, 43.26802437)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51242426, -43.02847335)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51242426, -43.02847335)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51242426, 0.13648347)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.51242426, 0.13648347)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.64818019, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.64818019, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.06279912, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.06279912, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.30492924, 0.13648346)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.30492924, 0.13648346)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (274.71954816, 0.13648346)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (274.71954816, 0.13648346)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.5122387, 43.26802437)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.5122387, 43.26802437)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.5122387, -43.02847335)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.5122387, -43.02847335)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.5122387, 0.13648346)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.5122387, 0.13648346)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.64818096, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (108.64818096, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.06279835, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (241.06279835, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85548965, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.30493, 0.13648346)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (142.30493, 0.13648346)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (274.71954739, 0.13648346)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (274.71954739, 0.13648346)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.5122387, 43.26802437)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.5122387, 43.26802437)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.5122387, -43.02847335)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.5122387, -43.02847335)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.5122387, 0.13648346)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.5122387, 0.13648346)> is outside valid IRF map range, using nearest IRF defined within
# CPU times: user 2min 30s, sys: 311 ms, total: 2min 30s
# Wall time: 2min 30s

# %% [markdown]
# The method `N_map()` is a map in the origial geometry with the nuisance parameters as the data. It is used in npred_background() and visualises the best fit nuisance parameters.

# %%
vmax = np.max(np.abs(dataset_N.N_map().data))
dataset_N.N_map().plot_grid(
    add_cbar=1, vmax=vmax, vmin=-vmax
);

# %% [markdown]
# ## Comparison to Standard Analysis

# %% [markdown]
# The spectral residual points show again how especially the first two energybins are not fitted well

# %%
dataset_standard.plot_residuals(kwargs_spectral=kwargs_spectral);

# %% [markdown]
# After including the nuisance parameters the model description is much better in the first two energy bins. This indicates that the method worked and has improved out analysis.

# %%
res_N = (
    dataset_N.residuals("diff/sqrt(model)")
    .slice_by_idx(dict(energy=slice(6, 8)))
    .smooth(0.1 * u.deg)
)
vmax = np.nanmax(np.abs(res_standard.data))
res_N.plot_grid(add_cbar=1, vmax=vmax, vmin=-vmax, cmap="coolwarm");

# %%
dataset_N.plot_residuals(kwargs_spectral=kwargs_spectral);
# Out:
# /home/hpc/caph/mppi045h/3D_analysis/N_parameters_in_L/HESS_3Dbkg_syserror/2-error_in_dataset/my_dataset_maps_20.py:1014: RuntimeWarning: invalid value encountered in true_divide
#   yerr = excess_error / np.sqrt(npred_spec.data)

# %% [markdown]
# Her a comparison of the distribution of the significance maps in the first two energy bins is shown. With the nuisance parameters the mean of the distribution $\mu$ got closer to zero and the standard deviation $\sigma$ is closer to the expected $1$.

# %%
res_standard = (
    dataset_standard.residuals("diff/sqrt(model)")
    .slice_by_idx(dict(energy=slice(i_start, i_end)))
    .data.flatten()
)
res_N = (
    dataset_N.residuals("diff/sqrt(model)")
    .slice_by_idx(dict(energy=slice(i_start, i_end)))
    .data.flatten()
)

_, bins, _ = plt.hist(
    res_standard,
    bins=50,
    alpha=0.4,
    label="Standard: \n$\mu$ = {:.3} \n$\sigma$ = {:.3}".format(
        np.nanmean(res_standard), np.nanstd(res_standard)
    ),
)
plt.hist(
    res_N,
    bins=bins,
    alpha=0.4,
    label="Nuisance: \n$\mu$ = {:.3} \n$\sigma$ = {:.3}".format(
        np.nanmean(res_N), np.nanstd(res_N)
    ),
)
plt.yscale("log")
plt.legend()
plt.xlabel("Significance")
plt.ylabel("Amount");

# %%
ax = dataset_standard.plot_residuals_spectral(method = kwargs_spectral["method"],
                                    region = kwargs_spectral["region"],
                                        color = 'red',
                                        label = "Standard Analysis")
ylim = ax.get_ylim()
dataset_N.plot_residuals_spectral(ax = ax ,method = kwargs_spectral["method"],
                                    region = kwargs_spectral["region"],
                                         color = 'green',
                                         label = "With Nuisance Par.")
ax.set_ylim(ylim[0], ylim[1])
eax = dataset_standard.geoms['geom'].axes[0].edges.value
print(eax)
ax.set_xlim(eax[6], eax[-1])
ax.legend(loc = 'lower right')
fig = plt.gcf()
name = f'plots/2_Spectral_Residuals.png'
fig.savefig(name, dpi=300, bbox_inches = 'tight')
name = f'plots/2_Spectral_Residuals.pdf'
fig.savefig(name, dpi=300, bbox_inches = 'tight')
# Out:
# /home/hpc/caph/mppi045h/3D_analysis/N_parameters_in_L/HESS_3Dbkg_syserror/2-error_in_dataset/my_dataset_maps_20.py:1014: RuntimeWarning: invalid value encountered in true_divide
#   yerr = excess_error / np.sqrt(npred_spec.data)
# [1.00000000e-01 1.33352143e-01 1.77827941e-01 2.37137371e-01
#  3.16227766e-01 4.21696503e-01 5.62341325e-01 7.49894209e-01
#  1.00000000e+00 1.33352143e+00 1.77827941e+00 2.37137371e+00
#  3.16227766e+00 4.21696503e+00 5.62341325e+00 7.49894209e+00
#  1.00000000e+01 1.33352143e+01 1.77827941e+01 2.37137371e+01
#  3.16227766e+01 4.21696503e+01 5.62341325e+01 7.49894209e+01
#  1.00000000e+02]

# %% [markdown]
# ## Comparsion of the erros of the best fit model parameters
#
# The model errors of the Nuisance dataset have for now to be set by hand.

# %% [markdown]
# ## Pseudo Dataset

# %%
dataset_pseudo = dataset_standard.copy()
dataset_pseudo.background = dataset_N.npred_background().copy()
bkg_model = FoVBackgroundModel(dataset_name=dataset_pseudo.name)
bkg_model.parameters["tilt"].frozen = False
models_pseudo = models.copy()
models_pseudo.append(bkg_model)
dataset_pseudo.models = models_pseudo

fit_pseudo = Fit(store_trace=False)
result_pseudo = fit_pseudo.run([dataset_pseudo])
# Out:
# Position <SkyCoord (Galactic): (l, b) in deg
#     (50.58881722, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (50.58881722, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (309.25520255, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (309.25520255, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (4.98869062, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (4.98869062, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (49.34512207, -0.25884741)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (49.34512207, -0.25884741)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (308.0115074, -0.25884741)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (308.0115074, -0.25884741)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (3.74499547, -0.25884741)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (3.74499547, -0.25884741)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (353.611634, -0.25884741)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (353.611634, -0.25884741)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (49.13678114, -1.1122907)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (49.13678114, -1.1122907)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (307.80316647, -1.1122907)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (307.80316647, -1.1122907)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (3.53665454, -1.1122907)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (3.53665454, -1.1122907)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (353.40329307, -1.1122907)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (353.40329307, -1.1122907)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (48.94663567, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (48.94663567, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (307.613021, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (307.613021, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (6.80931407, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (6.80931407, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (349.75034259, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (349.75034259, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (329.52192548, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (329.52192548, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (342.18862732, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (342.18862732, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.36199723, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.36199723, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.34866108, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.34866108, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.01769236)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.01769236)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (356.8439127, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (356.8439127, 0.13569917)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (349.78864842, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (349.78864842, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.36199723, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.36199723, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.34866108, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.34866108, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (349.78864842, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (349.78864842, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 0.32529846)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 0.32529846)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.367612)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.367612)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (45.52213649, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (45.52213649, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (304.18852182, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (304.18852182, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 3.44256397)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 3.44256397)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -3.48484647)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -3.48484647)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (141.52340249, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (141.52340249, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (208.18725581, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (208.18725581, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 33.77664346)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 33.77664346)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -33.81586064)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -33.81586064)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (21.53606256, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (21.53606256, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (328.17459574, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (328.17459574, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (261.66266328, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (261.66266328, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (88.04799503, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (88.04799503, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (111.87139621, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (111.87139621, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.83926209, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.83926209, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (111.88732149, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (111.88732149, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.82333682, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.82333682, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (111.90463966, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (111.90463966, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.80601864, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.80601864, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (111.91553861, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (111.91553861, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.79511969, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.79511969, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (111.91943059, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (111.91943059, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.79122772, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.79122772, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (111.93373163, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (111.93373163, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.77692668, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.77692668, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (111.93460356, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (111.93460356, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.77605475, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.77605475, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (111.99816005, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (111.99816005, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.71249826, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.71249826, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.00169767, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.00169767, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.70896063, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.70896063, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.02453736, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.02453736, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.68612094, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.68612094, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02114684)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02114684)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (356.54741122, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (356.54741122, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (353.16324708, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (353.16324708, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (352.19132821, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (352.19132821, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.12172925, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.12172925, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.58892906, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.58892906, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02105604)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02105604)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (352.19132821, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (352.19132821, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02014808)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02014808)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (21.49533854, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (21.49533854, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (328.21531977, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (328.21531977, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.01106852)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.01106852)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (261.255423, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (261.255423, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (88.4552353, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (88.4552353, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 0.07972714)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 0.07972714)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.12204096)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.12204096)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (138.85626764, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (138.85626764, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (210.85439066, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (210.85439066, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 0.98766401)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 0.98766401)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -1.0299752)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -1.0299752)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 10.04626972)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 10.04626972)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -10.08831801)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -10.08831801)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.07895308, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.07895308, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.63170522, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.63170522, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09285168, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09285168, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61780662, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61780662, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09572678, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09572678, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61493152, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61493152, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09638388, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09638388, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61427443, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61427443, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09654875, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09654875, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61410955, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61410955, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09676772, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09676772, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61389058, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61389058, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09691968, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09691968, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61373863, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61373863, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09701972, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09701972, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61363858, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61363858, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09710666, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09710666, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61355164, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61355164, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09720284, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09720284, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61345546, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61345546, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09728357, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09728357, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61337473, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61337473, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09736623, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09736623, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61329207, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61329207, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09744622, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09744622, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61321209, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61321209, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09751681, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09751681, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61314149, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61314149, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09754926, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09754926, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61310904, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61310904, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09756066, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09756066, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61309764, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61309764, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09756147, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09756147, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61309683, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61309683, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.0975698, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.0975698, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61308851, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61308851, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09756981, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (112.09756981, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61308849, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (237.61308849, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, 43.12973033)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -43.16686423)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.85532915, -0.02115692)> is outside valid IRF map range, using nearest IRF defined within

# %%
print(" with nuisance")
print("(without nuisance)")

for p_N, p_stand , p_pseudo in zip(dataset_N.models.parameters,
                                   dataset_standard.models.parameters,
                                  dataset_pseudo.models.parameters):
    print()
    print('='*50)
    print(p_N.name )
    print('-'*50)
    print(" {:.4} +- {:.3} +- {:.3}".format(p_N.value, float(p_pseudo.error) ,
                                            float(p_N.error)- float(p_pseudo.error)  )   ) 
    print('({:.4} +- {:.3})'.format(p_stand.value, float(p_stand.error) ))

# %%
added =  '00'+str(int(binsize[0].value* 100)) + '_' + str(i_start) + str(i_end)
print(added)

# %%
import yaml
save = 1
path_local_repo = '/home/hpc/caph/mppi045h/3D_analysis/N_parameters_in_L/syserror_3d_bkgmodel/2-source_dataset'


if save:
    print(f"save in: {path_local_repo}/{source}/nui_dataset_{added}.fits" )
    print(f"and: {path_local_repo}/nui_bgmodel_{added}.yml ")


    # save for now in this folder
    dataset_N.write(f'{path_local_repo}/{source}/nui_dataset_{added}.fits', overwrite = True)
    with open(f'{path_local_repo}/{source}/nui_par_{added}.yml', 'w') as outfile:
            yaml.dump(dataset_N.N_parameters.to_dict(), outfile, default_flow_style=False)
    with open(f'{path_local_repo}/{source}/nui_bgmodel_{added}.yml', 'w') as outfile:
            yaml.dump(dataset_N.background_model.to_dict(), outfile, default_flow_style=False)
    with open(f'{path_local_repo}/{source}/nui_model_{added}.yml', 'w') as outfile:
            yaml.dump(dataset_N.models.to_dict(), outfile, default_flow_style=False)        

    with open(f'{path_local_repo}/{source}/pseudo_bgmodel_{added}.yml', 'w') as outfile:
            yaml.dump(dataset_pseudo.background_model.to_dict(), outfile, default_flow_style=False)
    with open(f'{path_local_repo}/{source}/pseudo_model_{added}.yml', 'w') as outfile:
            yaml.dump(dataset_pseudo.models.to_dict(), outfile, default_flow_style=False)
